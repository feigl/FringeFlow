# %%
import cdsapi
# example https://cds-beta.climate.copernicus.eu/how-to-api#install-the-cds-api-token

client = cdsapi.Client()

dataset = 'reanalysis-era5-pressure-levels'
request = {
    'product_type': ['reanalysis'],
    'variable': ['geopotential'],
    'year': ['2024'],
    'month': ['03'],
    'day': ['01'],
    'time': ['13:00'],
    'pressure_level': ['1000'],
    'data_format': 'grib',
}
target = 'download.grib'

client.retrieve(dataset, request, target)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 19
#       7 request = {
#       8     'product_type': ['reanalysis'],
#       9     'variable': ['geopotential'],
#    (...)
#      15     'data_format': 'grib',
#      16 }
#      17 target = 'download.grib'
# ---> 19 client.retrieve(dataset, request, target)
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/legacy_api_client.py:160, in LegacyApiClient.retrieve(self, name, request, target)
#     158 submitted: processing.Remote | processing.Results
#     159 if self.wait_until_complete:
# --> 160     submitted = self.logging_decorator(self.client.submit_and_wait_on_result)(
#     161         collection_id=name,
#     162         **request,
#     163     )
#     164 else:
#     165     submitted = self.logging_decorator(self.client.submit)(
#     166         collection_id=name,
#     167         **request,
#     168     )
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/legacy_api_client.py:143, in LegacyApiClient.logging_decorator.<locals>.wrapper(*args, **kwargs)
#     138 @functools.wraps(func)
#     139 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     140     with LoggingContext(
#     141         logger=processing.logger, quiet=self.quiet, debug=self._debug
#     142     ):
# --> 143         return func(*args, **kwargs)
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/api_client.py:133, in ApiClient.submit_and_wait_on_result(self, collection_id, **request)
#     130 def submit_and_wait_on_result(
#     131     self, collection_id: str, **request: Any
#     132 ) -> processing.Results:
# --> 133     return self.retrieve_api.submit_and_wait_on_result(collection_id, **request)
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/processing.py:545, in Processing.submit_and_wait_on_result(self, collection_id, **request)
#     544 def submit_and_wait_on_result(self, collection_id: str, **request: Any) -> Results:
# --> 545     remote = self.submit(collection_id, **request)
#     546     remote.wait_on_result()
#     547     return remote.make_results()
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/processing.py:541, in Processing.submit(self, collection_id, **request)
#     540 def submit(self, collection_id: str, **request: Any) -> Remote:
# --> 541     status_info = self.process_execute(collection_id, request)
#     542     return status_info.make_remote()
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/processing.py:522, in Processing.process_execute(self, process_id, inputs)
#     516 def process_execute(
#     517     self,
#     518     process_id: str,
#     519     inputs: dict[str, Any],
#     520 ) -> StatusInfo:
#     521     url = f"{self.url}/processes/{process_id}/execute"
# --> 522     return StatusInfo.from_request(
#     523         "post", url, json={"inputs": inputs}, **self.request_kwargs
#     524     )
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/processing.py:123, in ApiResponse.from_request(cls, method, url, headers, session, retry_options, request_options, download_options, sleep_max, cleanup, **kwargs)
#     118 response = robust_request(
#     119     method, url, headers=headers, **request_options, **kwargs
#     120 )
#     121 logger.debug(f"REPLY {response.text}")
# --> 123 cads_raise_for_status(response)
#     125 self = cls(
#     126     response,
#     127     headers=headers,
#    (...)
#     133     cleanup=cleanup,
#     134 )
#     135 self.log_messages()
#
# File ~/miniforge/envs/mintpykf/lib/python3.12/site-packages/cads_api_client/processing.py:71, in cads_raise_for_status(response)
#      64     else:
#      65         message = "\n".join(
#      66             [
#      67                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      68                 error_json_to_message(error_json),
#      69             ]
#      70         )
# ---> 71         raise requests.exceptions.HTTPError(message, response=response)
#      72 response.raise_for_status()
#
# HTTPError: 403 Client Error: Forbidden for url: https://cds-beta.climate.copernicus.eu/api/retrieve/v1/processes/reanalysis-era5-pressure-levels/execute
# required licences not accepted
# required licences not accepted; please accept the following licences to proceed: [{'id': 'licence-to-use-copernicus-products', 'revision': 12}]
